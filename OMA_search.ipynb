# %% [markdown]
# <a href="https://colab.research.google.com/github/alibekk93/5-a-side-optimisation/blob/master/OMA_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# copy repo to get available datafiles

# !git clone https://github.com/alibekk93/IDP_analysis.git
# Out:
# Cloning into 'IDP_analysis'...
# remote: Enumerating objects: 604, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 604 (delta 69), reused 130 (delta 46), pack-reused 412
# Receiving objects: 100% (604/604), 227.60 MiB | 24.31 MiB/s, done.
# Resolving deltas: 100% (205/205), done.
# Checking out files: 100% (50/50), done.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tempura = pd.read_excel('/content/IDP_analysis/OMA_search/200617_TEMPURA.xlsx')

# %%
tempura.head()
# Out:
#        genus_and_species  taxonomy_id  strain superkingdom         phylum  \
# 0  Methanopyrus kandleri         2320     116      Archaea  Euryarchaeota
# 1      Geogemma barossii      1927912     121      Archaea  Crenarchaeota
# 2      Pyrolobus fumarii        54252      1A      Archaea  Crenarchaeota
# 3  Pyrococcus kukulkanii      1609559  NCB100      Archaea  Euryarchaeota
# 4  Methanopyrus kandleri         2320    AV19      Archaea  Euryarchaeota
#
#           class              order           family         genus  \
# 0   Methanopyri     Methanopyrales  Methanopyraceae  Methanopyrus
# 1  Thermoprotei  Desulfurococcales   Pyrodictiaceae      Geogemma
# 2  Thermoprotei  Desulfurococcales   Pyrodictiaceae     Pyrolobus
# 3   Thermococci     Thermococcales  Thermococcaceae    Pyrococcus
# 4   Methanopyri     Methanopyrales  Methanopyraceae  Methanopyrus
#
#   assembly_or_accession  ...  Genome_size  16S_accssion 16S_GC  Tmin  \
# ...

# %%
oma = pd.read_csv('/content/IDP_analysis/OMA_search/OMA_allSpecies.csv')

# %%
oma['genus_and_species'] = [' '.join(oma['Scientific Name'].iloc[i].split(' ')[:2]) for i in range(len(oma))]

# %%
oma.head()
# Out:
#     Code                      Scientific Name Common Name  Last Update  \
# 0  TREPP    Tremblaya princeps  (strain PCIT)         NaN  2013-Dec-17
# 1  HODCD  Hodgkinia cicadicola  (strain Dsem)         NaN  2013-May-28
# 2  CARRP       Carsonella ruddii  (strain PV)         NaN  2007-May-03
# 3  ZINIC  Zinderia insecticola  (strain CARI)         NaN  2013-Jan-10
# 4  SULMD       Sulcia muelleri  (strain DMIN)         NaN  2011-Sep-23
#
#    # of Sequences  NCBI TaxonId D.     genus_and_species
# 0             120        891398  B    Tremblaya princeps
# 1             169        573234  B  Hodgkinia cicadicola
# 2             182        387662  B     Carsonella ruddii
# 3             206        871271  B  Zinderia insecticola
# 4             226        641892  B       Sulcia muelleri

# %%
tempura_and_oma = pd.merge(left=tempura, right=oma, on='genus_and_species', how='inner')

# %%
tempura_and_oma.columns
# Out:
# Index(['genus_and_species', 'taxonomy_id', 'strain', 'superkingdom', 'phylum',
#        'class', 'order', 'family', 'genus', 'assembly_or_accession',
#        'Genome_GC', 'Genome_size', '16S_accssion', '16S_GC', 'Tmin',
#        'Topt_ave', 'Topt_low', 'Topt_high', 'Tmax', 'Tmax_Tmin', 'Expression',
#        'Code', 'Scientific Name', 'Common Name', 'Last Update',
#        '# of Sequences', 'NCBI TaxonId', 'D.'],
#       dtype='object')
